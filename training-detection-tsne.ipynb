# %%
import time
import pickle
import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
from sklearn.cluster import DBSCAN
from sklearn import svm
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler

from matplotlib import rcParams
rcParams['font.size'] = 14
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ### Definitions

# %%
# TSNE definitions
number_components = [x for x in range(1, 9)]

# %%
num_tests = 50 # number of tests to be performed and obtain average accuracy
samples_normal = 100
samples_abnormal = 15

# %%
# DBSCAN definitions
epsilon_configurations = [.1, .5, 1., 2., 3., 4., 5., 10.]
min_samples_configurations = [3, 5, 8, 10, 12, 15, 20, 50, 80, 100]

# %%
# OC-SVM definitions
gammas = [0.001, 0.1, 0.2, 0.5, 0.7, 1.0]
kernels = ['rbf', 'linear', 'sigmoid'] # , 'poly'
nus = [0.01, 0.1, .3, .5, .7, 1.]

# %%
folder = '/nobackup/carda/datasets/ml-simulation-optical/2019-ecoc-demo'

# %% [markdown]
# ### Importing dataset

# %%
with open(folder + '/compiled-dataset.h5', 'rb') as file:
    final_dataframe, scaled_dataframe, class_columns, class_names = pickle.load(file)
input_dim = final_dataframe.shape[1] - 3 # the last three columns are classes

# %% [markdown]
# ### Helper functions

# %%
# sort the OCSVM results dictionary by the performance
def get_sorted_pairs_ocsvm(performance):
    values = sorted([[performance[kernel][nu][gamma]['false_positive_rate'], performance[kernel][nu][gamma]['false_negative_rate']] for kernel in performance for nu in performance[kernel] for gamma in performance[kernel][nu]], key=lambda x: x[0])
    return values

# sort the DBSCAN results dictionary by the performance
def get_sorted_pairs_dbscan(performance):
    values = sorted([[performance[layer][epsilon]['false_positive_rate'], performance[layer][epsilon]['false_negative_rate']] for layer in performance for epsilon in performance[layer]], key=lambda x: x[0])
    return values

# get best OCSVM f1 score
def get_best_ocsvm(performance):
    best_f1 = .0
    best = None
    for kernel in performance.keys():
        for nu in performance[kernel].keys():
            for gamma in performance[kernel][nu].keys():
                if performance[kernel][nu][gamma]['f1_score'] > best_f1:
                    best_f1 = performance[kernel][nu][gamma]['f1_score']
                    best = performance[kernel][nu][gamma]
    return best

# get best DBSCAN f1 score
def get_best_dbscan(performance):
    best_f1 = .0
    best = None
    for min_samples in performance.keys():
        for epsilon in performance[min_samples].keys():
            if performance[min_samples][epsilon]['f1_score'] > best_f1:
                best_f1 = performance[min_samples][epsilon]['f1_score']
                best = performance[min_samples][epsilon]
    return best

def get_curve(sorted_pairs):
    curve_fpr = []
    curve_fnr = []

    last_x = sorted_pairs[0][0]
    last_y = sorted_pairs[0][1]

    curve_fpr.append(sorted_pairs[0][0])
    curve_fnr.append(sorted_pairs[0][1])
    
    for x, y in sorted_pairs:
        if x > curve_fpr[-1] and y < curve_fnr[-1]:
            curve_fpr.append(x)
            curve_fnr.append(y)
    return curve_fpr, curve_fnr

# %% [markdown]
# ### Running the algorithm with TSNE

# %%
tsne_dataframes = {}
for n_components in number_components:
    start_time = time.time()
    print('starting', n_components, '...')
    if n_components < 4:
        method = 'barnes_hut'
    else:
        method = 'exact'
    tsne = TSNE(n_components=n_components, verbose=1, n_iter=300, method=method)

    tsne_data = tsne.fit_transform(scaled_dataframe.drop(class_columns, axis=1))

    tsne_df = pd.DataFrame(data=tsne_data, columns=[f'tsne_{i}' for i in range(1, n_components+1)])

    class_df = pd.DataFrame(data=scaled_dataframe[class_columns], columns=class_columns)
    
    final_df = pd.concat([tsne_df, class_df], axis=1)
    tsne_dataframes[n_components] = final_df
    print('finished after {} seconds'.format(time.time() - start_time))

with open('./models/tsne_dataset.h5', 'wb') as file:
    pickle.dump({'tsne_dataframes': tsne_dataframes}, file)
# Out:
# starting 1 ...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 19882 samples in 0.072s...
# [t-SNE] Computed neighbors for 19882 samples in 5.076s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.427336
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.616592
# [t-SNE] KL divergence after 300 iterations: 4.217602
# finished after 44.05916166305542 seconds
# starting 2 ...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 19882 samples in 0.071s...
# [t-SNE] Computed neighbors for 19882 samples in 5.065s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.427336
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.674065
# [t-SNE] KL divergence after 300 iterations: 3.143990
# finished after 49.81283187866211 seconds
# starting 3 ...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 19882 samples in 0.079s...
# [t-SNE] Computed neighbors for 19882 samples in 4.788s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.427336
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.261993
# [t-SNE] KL divergence after 300 iterations: 2.773550
# finished after 69.75623655319214 seconds
# starting 4 ...
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.418762
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.837312
# [t-SNE] KL divergence after 300 iterations: 2.529205
# finished after 7029.235682487488 seconds
# starting 5 ...
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.418762
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.312808
# [t-SNE] KL divergence after 300 iterations: 2.338364
# finished after 6514.448021888733 seconds
# starting 6 ...
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.418762
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.056867
# [t-SNE] KL divergence after 300 iterations: 2.180024
# finished after 6718.582005262375 seconds
# starting 7 ...
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.418762
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.965404
# [t-SNE] KL divergence after 300 iterations: 2.084397
# finished after 7034.040384054184 seconds
# starting 8 ...
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19882
# [t-SNE] Computed conditional probabilities for sample 2000 / 19882
# [t-SNE] Computed conditional probabilities for sample 3000 / 19882
# [t-SNE] Computed conditional probabilities for sample 4000 / 19882
# [t-SNE] Computed conditional probabilities for sample 5000 / 19882
# [t-SNE] Computed conditional probabilities for sample 6000 / 19882
# [t-SNE] Computed conditional probabilities for sample 7000 / 19882
# [t-SNE] Computed conditional probabilities for sample 8000 / 19882
# [t-SNE] Computed conditional probabilities for sample 9000 / 19882
# [t-SNE] Computed conditional probabilities for sample 10000 / 19882
# [t-SNE] Computed conditional probabilities for sample 11000 / 19882
# [t-SNE] Computed conditional probabilities for sample 12000 / 19882
# [t-SNE] Computed conditional probabilities for sample 13000 / 19882
# [t-SNE] Computed conditional probabilities for sample 14000 / 19882
# [t-SNE] Computed conditional probabilities for sample 15000 / 19882
# [t-SNE] Computed conditional probabilities for sample 16000 / 19882
# [t-SNE] Computed conditional probabilities for sample 17000 / 19882
# [t-SNE] Computed conditional probabilities for sample 18000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19000 / 19882
# [t-SNE] Computed conditional probabilities for sample 19882 / 19882
# [t-SNE] Mean sigma: 0.418762
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 70.914057
# [t-SNE] KL divergence after 300 iterations: 2.003625
# finished after 19776.870525598526 seconds

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne_1", y="tsne_2",
    hue="attack",
    palette=sns.color_palette("hls", 7),
    data=tsne_dataframes[2],
    legend="full",
    alpha=0.3
)
plt.savefig('./figures/tsne_2dim.pdf')
plt.savefig('./figures/tsne_2dim.svg')
# plt.show()
plt.close()

# %% [markdown]
# ### Running DBSCAN

# %%
performance_dbscan_tsne = {}
highest_f1 = 0.

for n_components in number_components:
    performance_dbscan_tsne[n_components] = {}
    for idm, min_samples in enumerate(min_samples_configurations):
        performance_dbscan_tsne[n_components][min_samples] = {}
        for ide, epsilon in enumerate(epsilon_configurations):
            performance_dbscan_tsne[n_components][min_samples][epsilon] = {}

print('npca\tMinPts\tepsilon\t\tfpr\tfnr\tf1')
for n_components in number_components:
    working_df = tsne_dataframes[n_components]
    for idm, min_samples in enumerate(min_samples_configurations):

        for ide, epsilon in enumerate(epsilon_configurations):

            clf = DBSCAN(eps=epsilon, min_samples=min_samples, metric='euclidean')

            true_positives = []
            false_negatives = []
            true_negatives = []
            false_positives = []
            precisions = []
            recalls = []
            f1_scores = []

            for test in range(num_tests):
                p1 = working_df[(working_df['path_1'] == 1) & (working_df['attack'] == 0)].sample(samples_normal)
                p2 = working_df[(working_df['path_2'] == 1) & (working_df['attack'] == 0)].sample(samples_normal)
                x_data = np.concatenate((p1.values[:, :-3], p2.values[:, :-3]), axis=0)
                y_data = np.concatenate((p1.values[:, -1], p2.values[:, -1]), axis=0)

                # start copy
                for i in range(num_tests):
                    x_data_test = np.copy(x_data)
                    y_data_test = np.copy(y_data)
                    for clazz in range(1, len(class_names)):
                        x = working_df[(working_df['path_1'] == 1) & (working_df['attack'] == clazz)].sample(samples_abnormal)
                        x_data_test = np.concatenate((x_data_test, x.values[:, :-3]), axis=0)
                        y_data_test = np.concatenate((y_data_test, x.values[:, -1]), axis=0)

                        x = working_df[(working_df['path_2'] == 1) & (working_df['attack'] == clazz)].sample(samples_abnormal)
                        x_data_test = np.concatenate((x_data_test, x.values[:, :-3]), axis=0)
                        y_data_test = np.concatenate((y_data_test, x.values[:, -1]), axis=0)

                    y_pred = clf.fit_predict(x_data_test)

                    tpr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == -1 and y_data_test[i] > 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] > 0])
                    fnr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] >= 0 and y_data_test[i] > 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] > 0])

                    tnr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] >= 0 and y_data_test[i] == 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] == 0])
                    fpr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == -1 and y_data_test[i] == 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] == 0])

                    if tpr == 0: # avoids division by zero
                        precision = 0.
                        recall = 0.
                        f1 = 0.
                    else:
                        precision = tpr / (tpr + fpr)
                        recall = tpr / (tpr + fnr)
                        f1 = 2 * precision * recall / (precision + recall)

                    true_positives.append(tpr)
                    false_negatives.append(fnr)
                    true_negatives.append(tnr)
                    false_positives.append(fpr)
                    precisions.append(precision)
                    recalls.append(recall)
                    f1_scores.append(f1)

            performance_dbscan_tsne[n_components][min_samples][epsilon]['n_components'] = n_components
            performance_dbscan_tsne[n_components][min_samples][epsilon]['min_samples'] = min_samples
            performance_dbscan_tsne[n_components][min_samples][epsilon]['epsilon'] = epsilon
            
            performance_dbscan_tsne[n_components][min_samples][epsilon]['true_positive_rate'] = np.mean(true_positives)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['false_negative_rate'] = np.mean(false_negatives)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['true_negative_rate'] = np.mean(true_negatives)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['false_positive_rate'] = np.mean(false_positives)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['precision'] = np.mean(precisions)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['recall'] = np.mean(recalls)
            performance_dbscan_tsne[n_components][min_samples][epsilon]['f1_score'] = np.mean(f1_scores)
            msg = ''
            if performance_dbscan_tsne[n_components][min_samples][epsilon]['f1_score'] > highest_f1:
                msg = '\t * highest'
                highest_f1 = performance_dbscan_tsne[n_components][min_samples][epsilon]['f1_score']
            print(f'{n_components:>4}\t{min_samples:>6}\t', f'{epsilon:>6}', '\t{:.3f}\t{:.3f}\t{:.3f}\t'.format(performance_dbscan_tsne[n_components][min_samples][epsilon]['false_positive_rate'],
                    performance_dbscan_tsne[n_components][min_samples][epsilon]['false_negative_rate'],
                    performance_dbscan_tsne[n_components][min_samples][epsilon]['f1_score']), msg)

print('done')
# Out:
# npca	MinPts	epsilon		fpr	fnr	f1
#    1	     3	    0.1 	0.024	0.801	0.324	 	 * highest
#    1	     3	    0.5 	0.000	0.985	0.030
#    1	     3	    1.0 	0.000	0.994	0.012
#    1	     3	    2.0 	0.000	1.000	0.000
#    1	     3	    3.0 	0.000	1.000	0.000
#    1	     3	    4.0 	0.000	1.000	0.000
#    1	     3	    5.0 	0.000	1.000	0.000
#    1	     3	   10.0 	0.000	1.000	0.000
#    1	     5	    0.1 	0.071	0.558	0.583	 	 * highest
#    1	     5	    0.5 	0.000	0.952	0.091
#    1	     5	    1.0 	0.000	0.991	0.018
#    1	     5	    2.0 	0.000	1.000	0.000
#    1	     5	    3.0 	0.000	1.000	0.000
#    1	     5	    4.0 	0.000	1.000	0.000
#    1	     5	    5.0 	0.000	1.000	0.000
#    1	     5	   10.0 	0.000	1.000	0.000
#    1	     8	    0.1 	0.224	0.263	0.751	 	 * highest
#    1	     8	    0.5 	0.010	0.833	0.281
#    1	     8	    1.0 	0.000	0.983	0.033
#    1	     8	    2.0 	0.000	1.000	0.000
#    1	     8	    3.0 	0.000	1.000	0.000
#    1	     8	    4.0 	0.000	1.000	0.000
#    1	     8	    5.0 	0.000	1.000	0.000
#    1	     8	   10.0 	0.000	1.000	0.000
#    1	    10	    0.1 	0.345	0.151	0.774	 	 * highest
#    1	    10	    0.5 	0.016	0.704	0.447
#    1	    10	    1.0 	0.000	0.971	0.055
#    1	    10	    2.0 	0.000	1.000	0.000
#    1	    10	    3.0 	0.000	1.000	0.000
#    1	    10	    4.0 	0.000	1.000	0.000
#    1	    10	    5.0 	0.000	1.000	0.000
#    1	    10	   10.0 	0.000	1.000	0.000
#    1	    12	    0.1 	0.464	0.093	0.765
#    1	    12	    0.5 	0.026	0.572	0.585
#    1	    12	    1.0 	0.000	0.952	0.091
#    8	    10	    2.0 	0.075	0.162	0.876
#    8	    10	    3.0 	0.000	0.851	0.256
#    8	    10	    4.0 	0.000	1.000	0.000
#    8	    10	    5.0 	0.000	1.000	0.000
#    8	    10	   10.0 	0.000	1.000	0.000
#    8	    12	    0.1 	1.000	0.000	0.667
#    8	    12	    0.5 	1.000	0.000	0.667
#    8	    12	    1.0 	0.983	0.000	0.670
#    8	    12	    2.0 	0.153	0.128	0.862
#    8	    12	    3.0 	0.000	0.761	0.381
#    8	    12	    4.0 	0.000	1.000	0.001
#    8	    12	    5.0 	0.000	1.000	0.000
#    8	    12	   10.0 	0.000	1.000	0.000
#    8	    15	    0.1 	1.000	0.000	0.667
#    8	    15	    0.5 	1.000	0.000	0.667
#    8	    15	    1.0 	0.997	0.000	0.667
#    8	    15	    2.0 	0.294	0.081	0.831
#    8	    15	    3.0 	0.001	0.631	0.535
#    8	    15	    4.0 	0.000	0.999	0.001
#    8	    15	    5.0 	0.000	1.000	0.000
#    8	    15	   10.0 	0.000	1.000	0.000
#    8	    20	    0.1 	1.000	0.000	0.667
#    8	    20	    0.5 	1.000	0.000	0.667
#    8	    20	    1.0 	1.000	0.000	0.667
#    8	    20	    2.0 	0.660	0.022	0.743
#    8	    20	    3.0 	0.005	0.509	0.655
#    8	    20	    4.0 	0.000	0.999	0.003
#    8	    20	    5.0 	0.000	1.000	0.000
#    8	    20	   10.0 	0.000	1.000	0.000
#    8	    50	    0.1 	1.000	0.000	0.667
#    8	    50	    0.5 	1.000	0.000	0.667
#    8	    50	    1.0 	1.000	0.000	0.667
#    8	    50	    2.0 	1.000	0.000	0.667
#    8	    50	    3.0 	0.541	0.098	0.740
#    8	    50	    4.0 	0.000	0.979	0.041
#    8	    50	    5.0 	0.000	1.000	0.000
#    8	    50	   10.0 	0.000	1.000	0.000
#    8	    80	    0.1 	1.000	0.000	0.667
#    8	    80	    0.5 	1.000	0.000	0.667
#    8	    80	    1.0 	1.000	0.000	0.667
#    8	    80	    2.0 	1.000	0.000	0.667
#    8	    80	    3.0 	1.000	0.000	0.667
#    8	    80	    4.0 	0.057	0.853	0.239
#    8	    80	    5.0 	0.000	1.000	0.000
#    8	    80	   10.0 	0.000	1.000	0.000
#    8	   100	    0.1 	1.000	0.000	0.667
#    8	   100	    0.5 	1.000	0.000	0.667
#    8	   100	    1.0 	1.000	0.000	0.667
#    8	   100	    2.0 	1.000	0.000	0.667
#    8	   100	    3.0 	1.000	0.000	0.667
#    8	   100	    4.0 	0.153	0.691	0.414
#    8	   100	    5.0 	0.000	1.000	0.000
#    8	   100	   10.0 	0.000	1.000	0.000
# done

# %%
plt.figure()

for n_components in performance_dbscan_tsne.keys():
    
    sorted_pairs = get_sorted_pairs_dbscan(performance_dbscan_tsne[n_components])
    curve_fpr, curve_fnr = get_curve(sorted_pairs)
    
    best_f1 = get_best_dbscan(performance_dbscan_tsne[n_components])
    
    ax = plt.scatter([x for x, y in sorted_pairs if x not in curve_fpr and y not in curve_fnr], 
                [y for x, y in sorted_pairs if x not in curve_fpr and y not in curve_fnr], 
                marker='o', s=80, alpha=0.5, edgecolors='white', zorder=1)
    
    plt.plot(curve_fpr, curve_fnr, ls='--', marker='o', alpha=1., markeredgecolor='white', color=ax.get_facecolors()[0], zorder=10, label=f"{n_components} ({best_f1['f1_score']:.3f})")
    
    plt.annotate(f"{n_components} comp\nf1: {best_f1['f1_score']:.3f}", 
                 xy=(best_f1['false_positive_rate'], best_f1['false_negative_rate']), xycoords='data', 
                 xytext=(-0.05+n_components*.1, 0.9-n_components*.1), textcoords='data',
                 color=ax.get_facecolors()[0],alpha=1.,
                 arrowprops=dict(arrowstyle='->'),
                 zorder=20)
    
plt.xlabel('false positive')
plt.ylabel('false negative')
plt.legend(ncol=2)
plt.tight_layout()
plt.savefig('./figures/tsne_dbscan.pdf')
plt.savefig('./figures/tsne_dbscan.svg')
plt.show()

# %% [markdown]
# ### Running OC-SVM

# %%
performance_ocsvm_tsne = {}
highest_f1 = .0

for n_components in number_components:
    performance_ocsvm_tsne[n_components] = {}
    for kernel in kernels:
        performance_ocsvm_tsne[n_components][kernel] = {}
        for nu in nus:
            performance_ocsvm_tsne[n_components][kernel][nu] = {}
            for gamma in gammas:
                performance_ocsvm_tsne[n_components][kernel][nu][gamma] = {}

print('npca\t    kernel\t    nu\t gamma\t\tfpr\tfnr\tf1')
for n_components in number_components:
    working_df = tsne_dataframes[n_components]
    for kernel in kernels:
        for nu in nus:
            for gamma in gammas:

                clf = svm.OneClassSVM(nu=nu, kernel=kernel, gamma=gamma)
                true_positives = []
                false_negatives = []
                true_negatives = []
                false_positives = []
                precisions = []
                recalls = []
                f1_scores = []
                for i in range(num_tests):
                    p1 = working_df[(working_df['path_1'] == 1) & (working_df['attack'] == 0)].sample(samples_normal)
                    p2 = working_df[(working_df['path_2'] == 1) & (working_df['attack'] == 0)].sample(samples_normal)
                    x_data = np.concatenate((p1.values[:, :-3], p2.values[:, :-3]), axis=0)
                    y_data = np.concatenate((p1.values[:, -1], p2.values[:, -1]), axis=0)

                    clf.fit(x_data)

                    for test in range(num_tests):
                        x_data_test = np.copy(x_data)
                        y_data_test = np.copy(y_data)
                        for clazz in range(1, len(class_names)):
                            x = working_df[(working_df['path_1'] == 1) & (working_df['attack'] == clazz)].sample(samples_abnormal)
                            x_data_test = np.concatenate((x_data_test, x.values[:, :-3]), axis=0)
                            y_data_test = np.concatenate((y_data_test, x.values[:, -1]), axis=0)

                            x = working_df[(working_df['path_2'] == 1) & (working_df['attack'] == clazz)].sample(samples_abnormal)
                            x_data_test = np.concatenate((x_data_test, x.values[:, :-3]), axis=0)
                            y_data_test = np.concatenate((y_data_test, x.values[:, -1]), axis=0)

                        y_pred = clf.predict(x_data_test)

                        tpr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == -1 and y_data_test[i] > 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] > 0])
                        fnr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == 1 and y_data_test[i] > 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] > 0])

                        tnr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == 1 and y_data_test[i] == 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] == 0])
                        fpr = np.sum([1 for i in range(len(y_pred)) if y_pred[i] == -1 and y_data_test[i] == 0]) / np.sum([1 for i in range(len(y_pred)) if y_data_test[i] == 0])

                        if tpr == 0: # avoids division by zero
                            precision = 0.
                            recall = 0.
                            f1 = 0.
                        else:
                            precision = tpr / (tpr + fpr)
                            recall = tpr / (tpr + fnr)
                            f1 = 2 * precision * recall / (precision + recall)

                        true_positives.append(tpr)
                        false_negatives.append(fnr)
                        true_negatives.append(tnr)
                        false_positives.append(fpr)
                        precisions.append(precision)
                        recalls.append(recall)
                        f1_scores.append(f1)

                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['n_components'] = n_components
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['kernel'] = kernel
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['nu'] = nu
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['gamma'] = gamma
                
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['true_positive_rate'] = np.mean(true_positives)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['false_negative_rate'] = np.mean(false_negatives)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['true_negative_rate'] = np.mean(true_negatives)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['false_positive_rate'] = np.mean(false_positives)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['precision'] = np.mean(precisions)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['recall'] = np.mean(recalls)
                performance_ocsvm_tsne[n_components][kernel][nu][gamma]['f1_score'] = np.mean(f1_scores)
                msg = ''
                if performance_ocsvm_tsne[n_components][kernel][nu][gamma]['f1_score'] > highest_f1:
                    msg = '\t * highest'
                    highest_f1 = performance_ocsvm_tsne[n_components][kernel][nu][gamma]['f1_score']
                print(f'{n_components:>4}\t{kernel:>10}\t', f'{nu:>6}\t', f'{gamma:>6}', '\t{:.3f}\t{:.3f}\t{:.3f}\t'.format(performance_ocsvm_tsne[n_components][kernel][nu][gamma]['false_positive_rate'],
                        performance_ocsvm_tsne[n_components][kernel][nu][gamma]['false_negative_rate'],
                        performance_ocsvm_tsne[n_components][kernel][nu][gamma]['f1_score']), msg)
print('done')
# Out:
# npca	    kernel	    nu	 gamma		fpr	fnr	f1
#    1	       rbf	   0.01	  0.001 	0.013	0.555	0.610	 	 * highest
#    1	       rbf	   0.01	    0.1 	0.074	0.299	0.789	 	 * highest
#    1	       rbf	   0.01	    0.2 	0.069	0.320	0.778
#    1	       rbf	   0.01	    0.5 	0.125	0.228	0.814	 	 * highest
#    1	       rbf	   0.01	    0.7 	0.117	0.240	0.810
#    1	       rbf	   0.01	    1.0 	0.146	0.256	0.787
#    1	       rbf	    0.1	  0.001 	0.101	0.543	0.586
#    1	       rbf	    0.1	    0.1 	0.105	0.262	0.800
#    1	       rbf	    0.1	    0.2 	0.104	0.263	0.800
#    1	       rbf	    0.1	    0.5 	0.142	0.190	0.830	 	 * highest
#    1	       rbf	    0.1	    0.7 	0.118	0.200	0.833	 	 * highest
#    1	       rbf	    0.1	    1.0 	0.141	0.227	0.808
#    1	       rbf	    0.3	  0.001 	0.299	0.491	0.563
#    1	       rbf	    0.3	    0.1 	0.302	0.202	0.760
#    1	       rbf	    0.3	    0.2 	0.298	0.199	0.763
#    1	       rbf	    0.3	    0.5 	0.313	0.141	0.791
#    1	       rbf	    0.3	    0.7 	0.306	0.129	0.800
#    1	       rbf	    0.3	    1.0 	0.302	0.144	0.793
#    1	       rbf	    0.5	  0.001 	0.499	0.427	0.553
#    1	       rbf	    0.5	    0.1 	0.499	0.148	0.725
#    1	       rbf	    0.5	    0.2 	0.500	0.141	0.728
#    1	       rbf	    0.5	    0.5 	0.505	0.126	0.735
#    1	       rbf	    0.5	    0.7 	0.502	0.118	0.740
#    1	       rbf	    0.5	    1.0 	0.500	0.101	0.749
#    1	       rbf	    0.7	  0.001 	0.701	0.389	0.528
#    1	       rbf	    0.7	    0.1 	0.700	0.096	0.694
#    1	       rbf	    0.7	    0.2 	0.703	0.105	0.689
#    1	       rbf	    0.7	    0.5 	0.701	0.089	0.697
#    1	       rbf	    0.7	    0.7 	0.702	0.084	0.700
#    1	       rbf	    0.7	    1.0 	0.700	0.072	0.706
#    1	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    1	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    1	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    1	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    1	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    1	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    1	    linear	   0.01	  0.001 	0.376	0.529	0.469
#    1	    linear	   0.01	    0.1 	0.380	0.487	0.506
#    1	    linear	   0.01	    0.2 	0.394	0.532	0.471
#    1	    linear	   0.01	    0.5 	0.350	0.554	0.465
#    1	    linear	   0.01	    0.7 	0.354	0.588	0.429
#    1	    linear	   0.01	    1.0 	0.346	0.597	0.418
#    1	    linear	    0.1	  0.001 	0.131	0.632	0.457
#    1	    linear	    0.1	    0.1 	0.146	0.596	0.502
#    1	    linear	    0.1	    0.2 	0.141	0.608	0.485
#    1	    linear	    0.1	    0.5 	0.080	0.651	0.470
#    1	    linear	    0.1	    0.7 	0.129	0.629	0.467
#    1	    linear	    0.1	    1.0 	0.100	0.639	0.466
#    1	    linear	    0.3	  0.001 	0.162	0.544	0.561
#    1	    linear	    0.3	    0.1 	0.214	0.530	0.553
#    1	    linear	    0.3	    0.2 	0.226	0.526	0.551
#    1	    linear	    0.3	    0.5 	0.222	0.530	0.550
#    1	    linear	    0.3	    0.7 	0.254	0.516	0.554
#    1	    linear	    0.3	    1.0 	0.210	0.536	0.550
#    1	    linear	    0.5	  0.001 	0.430	0.403	0.588
#    1	    linear	    0.5	    0.1 	0.470	0.380	0.592
#    1	   sigmoid	    1.0	    0.1 	1.000	0.000	0.667
#    1	   sigmoid	    1.0	    0.2 	1.000	0.000	0.667
#    1	   sigmoid	    1.0	    0.5 	1.000	0.000	0.667
#    1	   sigmoid	    1.0	    0.7 	1.000	0.000	0.667
#    1	   sigmoid	    1.0	    1.0 	1.000	0.000	0.667
#    2	       rbf	   0.01	  0.001 	0.007	0.660	0.503
#    2	       rbf	   0.01	    0.1 	0.069	0.119	0.904	 	 * highest
#    2	       rbf	   0.01	    0.2 	0.094	0.076	0.916	 	 * highest
#    2	       rbf	   0.01	    0.5 	0.153	0.045	0.906
#    2	       rbf	   0.01	    0.7 	0.178	0.037	0.900
#    2	       rbf	   0.01	    1.0 	0.204	0.028	0.893
#    2	       rbf	    0.1	  0.001 	0.099	0.596	0.537
#    2	       rbf	    0.1	    0.1 	0.103	0.099	0.899
#    2	       rbf	    0.1	    0.2 	0.102	0.070	0.915
#    2	       rbf	    0.1	    0.5 	0.134	0.047	0.914
#    2	       rbf	    0.1	    0.7 	0.157	0.037	0.909
#    2	       rbf	    0.1	    1.0 	0.183	0.027	0.902
#    2	       rbf	    0.3	  0.001 	0.300	0.491	0.563
#    2	       rbf	    0.3	    0.1 	0.300	0.057	0.841
#    2	       rbf	    0.3	    0.2 	0.303	0.027	0.855
#    2	       rbf	    0.3	    0.5 	0.307	0.025	0.855
#    2	       rbf	    0.3	    0.7 	0.303	0.019	0.859
#    2	       rbf	    0.3	    1.0 	0.312	0.019	0.855
#    2	       rbf	    0.5	  0.001 	0.500	0.331	0.616
#    2	       rbf	    0.5	    0.1 	0.501	0.028	0.786
#    2	       rbf	    0.5	    0.2 	0.498	0.012	0.795
#    2	       rbf	    0.5	    0.5 	0.499	0.012	0.795
#    2	       rbf	    0.5	    0.7 	0.498	0.010	0.796
#    2	       rbf	    0.5	    1.0 	0.502	0.009	0.795
#    2	       rbf	    0.7	  0.001 	0.701	0.193	0.643
#    2	       rbf	    0.7	    0.1 	0.699	0.013	0.735
#    2	       rbf	    0.7	    0.2 	0.697	0.004	0.740
#    2	       rbf	    0.7	    0.5 	0.701	0.004	0.739
#    2	       rbf	    0.7	    0.7 	0.696	0.003	0.740
#    2	       rbf	    0.7	    1.0 	0.698	0.003	0.740
#    2	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    2	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    2	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    2	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    2	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    2	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    2	    linear	   0.01	  0.001 	0.317	0.515	0.530
#    2	    linear	   0.01	    0.1 	0.359	0.463	0.564
#    2	    linear	   0.01	    0.2 	0.339	0.490	0.549
#    2	    linear	   0.01	    0.5 	0.345	0.495	0.542
#    2	    linear	   0.01	    0.7 	0.340	0.497	0.543
#    2	    linear	   0.01	    1.0 	0.366	0.509	0.525
#    3	       rbf	    0.7	    0.7 	0.693	0.001	0.742
#    3	       rbf	    0.7	    1.0 	0.692	0.001	0.743
#    3	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    3	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    3	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    3	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    3	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    3	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    3	    linear	   0.01	  0.001 	0.428	0.532	0.490
#    3	    linear	   0.01	    0.1 	0.405	0.556	0.477
#    3	    linear	   0.01	    0.2 	0.419	0.552	0.477
#    3	    linear	   0.01	    0.5 	0.409	0.571	0.464
#    3	    linear	   0.01	    0.7 	0.460	0.536	0.479
#    3	    linear	   0.01	    1.0 	0.438	0.538	0.486
#    3	    linear	    0.1	  0.001 	0.452	0.529	0.489
#    3	    linear	    0.1	    0.1 	0.510	0.532	0.472
#    3	    linear	    0.1	    0.2 	0.468	0.512	0.498
#    3	    linear	    0.1	    0.5 	0.499	0.535	0.472
#    3	    linear	    0.1	    0.7 	0.541	0.515	0.477
#    3	    linear	    0.1	    1.0 	0.543	0.492	0.494
#    3	    linear	    0.3	  0.001 	0.495	0.453	0.534
#    3	    linear	    0.3	    0.1 	0.493	0.517	0.488
#    3	    linear	    0.3	    0.2 	0.531	0.527	0.470
#    3	    linear	    0.3	    0.5 	0.511	0.501	0.496
#    3	    linear	    0.3	    0.7 	0.488	0.511	0.493
#    3	    linear	    0.3	    1.0 	0.490	0.523	0.482
#    3	    linear	    0.5	  0.001 	0.483	0.491	0.509
#    3	    linear	    0.5	    0.1 	0.524	0.474	0.510
#    3	    linear	    0.5	    0.2 	0.510	0.442	0.537
#    3	    linear	    0.5	    0.5 	0.487	0.449	0.539
#    3	    linear	    0.5	    0.7 	0.518	0.478	0.509
#    3	    linear	    0.5	    1.0 	0.482	0.473	0.520
#    3	    linear	    0.7	  0.001 	0.678	0.162	0.662
#    3	    linear	    0.7	    0.1 	0.659	0.206	0.639
#    3	    linear	    0.7	    0.2 	0.667	0.185	0.649
#    3	    linear	    0.7	    0.5 	0.674	0.174	0.656
#    3	    linear	    0.7	    0.7 	0.699	0.131	0.676
#    3	    linear	    0.7	    1.0 	0.694	0.149	0.666
#    3	    linear	    1.0	  0.001 	1.000	0.000	0.667
#    3	    linear	    1.0	    0.1 	1.000	0.000	0.667
#    3	    linear	    1.0	    0.2 	1.000	0.000	0.667
#    3	    linear	    1.0	    0.5 	1.000	0.000	0.667
#    3	    linear	    1.0	    0.7 	1.000	0.000	0.667
#    3	    linear	    1.0	    1.0 	1.000	0.000	0.667
#    3	   sigmoid	   0.01	  0.001 	0.412	0.541	0.490
#    3	   sigmoid	   0.01	    0.1 	0.009	0.973	0.050
#    3	   sigmoid	   0.01	    0.2 	0.011	0.973	0.051
#    3	   sigmoid	   0.01	    0.5 	0.026	0.961	0.072
#    3	   sigmoid	   0.01	    0.7 	0.057	0.956	0.076
#    4	       rbf	    0.3	    0.5 	0.302	0.005	0.866
#    4	       rbf	    0.3	    0.7 	0.299	0.005	0.868
#    4	       rbf	    0.3	    1.0 	0.307	0.004	0.865
#    4	       rbf	    0.5	  0.001 	0.501	0.281	0.647
#    4	       rbf	    0.5	    0.1 	0.502	0.020	0.790
#    4	       rbf	    0.5	    0.2 	0.499	0.005	0.798
#    4	       rbf	    0.5	    0.5 	0.500	0.002	0.799
#    4	       rbf	    0.5	    0.7 	0.494	0.002	0.801
#    4	       rbf	    0.5	    1.0 	0.488	0.002	0.803
#    4	       rbf	    0.7	  0.001 	0.701	0.123	0.680
#    4	       rbf	    0.7	    0.1 	0.699	0.009	0.737
#    4	       rbf	    0.7	    0.2 	0.699	0.001	0.741
#    4	       rbf	    0.7	    0.5 	0.694	0.001	0.742
#    4	       rbf	    0.7	    0.7 	0.695	0.001	0.742
#    4	       rbf	    0.7	    1.0 	0.692	0.001	0.743
#    4	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    4	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    4	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    4	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    4	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    4	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    4	    linear	   0.01	  0.001 	0.274	0.572	0.500
#    4	    linear	   0.01	    0.1 	0.307	0.551	0.509
#    4	    linear	   0.01	    0.2 	0.292	0.561	0.508
#    4	    linear	   0.01	    0.5 	0.300	0.555	0.509
#    4	    linear	   0.01	    0.7 	0.295	0.553	0.513
#    4	    linear	   0.01	    1.0 	0.298	0.564	0.500
#    4	    linear	    0.1	  0.001 	0.384	0.509	0.522
#    4	    linear	    0.1	    0.1 	0.402	0.504	0.522
#    4	    linear	    0.1	    0.2 	0.398	0.481	0.539
#    4	    linear	    0.1	    0.5 	0.426	0.476	0.536
#    4	    linear	    0.1	    0.7 	0.393	0.484	0.540
#    4	    linear	    0.1	    1.0 	0.415	0.487	0.532
#    4	    linear	    0.3	  0.001 	0.432	0.454	0.549
#    4	    linear	    0.3	    0.1 	0.414	0.467	0.544
#    4	    linear	    0.3	    0.2 	0.402	0.447	0.562
#    4	    linear	    0.3	    0.5 	0.443	0.453	0.547
#    4	    linear	    0.3	    0.7 	0.422	0.465	0.544
#    4	    linear	    0.3	    1.0 	0.419	0.461	0.549
#    4	    linear	    0.5	  0.001 	0.514	0.361	0.593
#    4	    linear	    0.5	    0.1 	0.503	0.359	0.597
#    4	    linear	    0.5	    0.2 	0.517	0.341	0.605
#    4	    linear	    0.5	    0.5 	0.515	0.360	0.593
#    4	    linear	    0.5	    0.7 	0.514	0.366	0.589
#    4	    linear	    0.5	    1.0 	0.510	0.347	0.604
#    4	    linear	    0.7	  0.001 	0.700	0.267	0.602
#    4	    linear	    0.7	    0.1 	0.699	0.264	0.604
#    4	    linear	    0.7	    0.2 	0.699	0.261	0.606
#    4	    linear	    0.7	    0.5 	0.698	0.265	0.604
#    5	       rbf	   0.01	    0.2 	0.159	0.020	0.916
#    5	       rbf	   0.01	    0.5 	0.262	0.005	0.881
#    5	       rbf	   0.01	    0.7 	0.310	0.004	0.864
#    5	       rbf	   0.01	    1.0 	0.343	0.003	0.853
#    5	       rbf	    0.1	  0.001 	0.101	0.789	0.320
#    5	       rbf	    0.1	    0.1 	0.107	0.086	0.904
#    5	       rbf	    0.1	    0.2 	0.149	0.019	0.921
#    5	       rbf	    0.1	    0.5 	0.243	0.005	0.889
#    5	       rbf	    0.1	    0.7 	0.286	0.004	0.873
#    5	       rbf	    0.1	    1.0 	0.324	0.002	0.860
#    5	       rbf	    0.3	  0.001 	0.298	0.596	0.474
#    5	       rbf	    0.3	    0.1 	0.304	0.052	0.842
#    5	       rbf	    0.3	    0.2 	0.305	0.010	0.863
#    5	       rbf	    0.3	    0.5 	0.307	0.004	0.865
#    5	       rbf	    0.3	    0.7 	0.296	0.004	0.869
#    5	       rbf	    0.3	    1.0 	0.323	0.003	0.859
#    5	       rbf	    0.5	  0.001 	0.500	0.369	0.591
#    5	       rbf	    0.5	    0.1 	0.500	0.026	0.787
#    5	       rbf	    0.5	    0.2 	0.500	0.003	0.799
#    5	       rbf	    0.5	    0.5 	0.492	0.002	0.802
#    5	       rbf	    0.5	    0.7 	0.490	0.002	0.802
#    5	       rbf	    0.5	    1.0 	0.481	0.002	0.805
#    5	       rbf	    0.7	  0.001 	0.699	0.180	0.651
#    5	       rbf	    0.7	    0.1 	0.701	0.010	0.736
#    5	       rbf	    0.7	    0.2 	0.699	0.001	0.741
#    5	       rbf	    0.7	    0.5 	0.692	0.001	0.743
#    5	       rbf	    0.7	    0.7 	0.695	0.001	0.742
#    5	       rbf	    0.7	    1.0 	0.681	0.001	0.745
#    5	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    5	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    5	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    5	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    5	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    5	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    5	    linear	   0.01	  0.001 	0.326	0.606	0.457
#    5	    linear	   0.01	    0.1 	0.289	0.614	0.460
#    5	    linear	   0.01	    0.2 	0.288	0.610	0.462
#    5	    linear	   0.01	    0.5 	0.310	0.621	0.449
#    5	    linear	   0.01	    0.7 	0.299	0.616	0.455
#    5	    linear	   0.01	    1.0 	0.288	0.608	0.465
#    5	    linear	    0.1	  0.001 	0.440	0.537	0.486
#    5	    linear	    0.1	    0.1 	0.469	0.531	0.482
#    5	    linear	    0.1	    0.2 	0.424	0.543	0.485
#    5	    linear	    0.1	    0.5 	0.456	0.536	0.482
#    5	    linear	    0.1	    0.7 	0.433	0.546	0.480
#    5	    linear	    0.1	    1.0 	0.453	0.529	0.488
#    5	    linear	    0.3	  0.001 	0.481	0.497	0.506
#    5	    linear	    0.3	    0.1 	0.479	0.503	0.502
#    7	       rbf	    0.7	  0.001 	0.700	0.106	0.689
#    7	       rbf	    0.7	    0.1 	0.701	0.024	0.729
#    7	       rbf	    0.7	    0.2 	0.701	0.001	0.740
#    7	       rbf	    0.7	    0.5 	0.695	0.001	0.742
#    7	       rbf	    0.7	    0.7 	0.687	0.001	0.744
#    7	       rbf	    0.7	    1.0 	0.679	0.001	0.746
#    7	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    7	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    7	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    7	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    7	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    7	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    7	    linear	   0.01	  0.001 	0.019	0.505	0.654
#    7	    linear	   0.01	    0.1 	0.023	0.506	0.651
#    7	    linear	   0.01	    0.2 	0.020	0.509	0.650
#    7	    linear	   0.01	    0.5 	0.021	0.509	0.649
#    7	    linear	   0.01	    0.7 	0.019	0.509	0.650
#    7	    linear	   0.01	    1.0 	0.021	0.509	0.649
#    7	    linear	    0.1	  0.001 	0.101	0.453	0.663
#    7	    linear	    0.1	    0.1 	0.098	0.458	0.661
#    7	    linear	    0.1	    0.2 	0.100	0.455	0.662
#    7	    linear	    0.1	    0.5 	0.099	0.457	0.661
#    7	    linear	    0.1	    0.7 	0.098	0.451	0.666
#    7	    linear	    0.1	    1.0 	0.100	0.448	0.668
#    7	    linear	    0.3	  0.001 	0.300	0.329	0.680
#    7	    linear	    0.3	    0.1 	0.300	0.333	0.678
#    7	    linear	    0.3	    0.2 	0.299	0.325	0.684
#    7	    linear	    0.3	    0.5 	0.299	0.320	0.687
#    7	    linear	    0.3	    0.7 	0.300	0.325	0.683
#    7	    linear	    0.3	    1.0 	0.301	0.323	0.684
#    7	    linear	    0.5	  0.001 	0.499	0.194	0.699
#    7	    linear	    0.5	    0.1 	0.500	0.191	0.700
#    7	    linear	    0.5	    0.2 	0.500	0.192	0.700
#    7	    linear	    0.5	    0.5 	0.499	0.193	0.699
#    7	    linear	    0.5	    0.7 	0.500	0.200	0.695
#    7	    linear	    0.5	    1.0 	0.499	0.198	0.697
#    7	    linear	    0.7	  0.001 	0.700	0.095	0.695
#    7	    linear	    0.7	    0.1 	0.700	0.090	0.697
#    7	    linear	    0.7	    0.2 	0.699	0.092	0.696
#    7	    linear	    0.7	    0.5 	0.700	0.091	0.697
#    7	    linear	    0.7	    0.7 	0.701	0.098	0.693
#    7	    linear	    0.7	    1.0 	0.699	0.092	0.696
#    7	    linear	    1.0	  0.001 	1.000	0.000	0.667
#    7	    linear	    1.0	    0.1 	1.000	0.000	0.667
#    7	    linear	    1.0	    0.2 	1.000	0.000	0.667
#    7	    linear	    1.0	    0.5 	1.000	0.000	0.667
#    7	    linear	    1.0	    0.7 	1.000	0.000	0.667
#    7	    linear	    1.0	    1.0 	1.000	0.000	0.667
#    7	   sigmoid	   0.01	  0.001 	0.199	0.442	0.636
#    8	       rbf	    0.1	    1.0 	0.358	0.002	0.847
#    8	       rbf	    0.3	  0.001 	0.300	0.484	0.567
#    8	       rbf	    0.3	    0.1 	0.300	0.057	0.841
#    8	       rbf	    0.3	    0.2 	0.305	0.010	0.863
#    8	       rbf	    0.3	    0.5 	0.302	0.003	0.867
#    8	       rbf	    0.3	    0.7 	0.312	0.002	0.864
#    8	       rbf	    0.3	    1.0 	0.349	0.002	0.851
#    8	       rbf	    0.5	  0.001 	0.501	0.299	0.636
#    8	       rbf	    0.5	    0.1 	0.501	0.035	0.783
#    8	       rbf	    0.5	    0.2 	0.496	0.004	0.799
#    8	       rbf	    0.5	    0.5 	0.499	0.001	0.800
#    8	       rbf	    0.5	    0.7 	0.491	0.001	0.802
#    8	       rbf	    0.5	    1.0 	0.462	0.001	0.812
#    8	       rbf	    0.7	  0.001 	0.700	0.158	0.662
#    8	       rbf	    0.7	    0.1 	0.701	0.015	0.733
#    8	       rbf	    0.7	    0.2 	0.697	0.002	0.741
#    8	       rbf	    0.7	    0.5 	0.693	0.000	0.743
#    8	       rbf	    0.7	    0.7 	0.685	0.000	0.745
#    8	       rbf	    0.7	    1.0 	0.676	0.000	0.747
#    8	       rbf	    1.0	  0.001 	1.000	0.000	0.667
#    8	       rbf	    1.0	    0.1 	1.000	0.000	0.667
#    8	       rbf	    1.0	    0.2 	1.000	0.000	0.667
#    8	       rbf	    1.0	    0.5 	1.000	0.000	0.667
#    8	       rbf	    1.0	    0.7 	1.000	0.000	0.667
#    8	       rbf	    1.0	    1.0 	1.000	0.000	0.667
#    8	    linear	   0.01	  0.001 	0.243	0.581	0.504
#    8	    linear	   0.01	    0.1 	0.253	0.601	0.482
#    8	    linear	   0.01	    0.2 	0.259	0.582	0.498
#    8	    linear	   0.01	    0.5 	0.255	0.582	0.499
#    8	    linear	   0.01	    0.7 	0.242	0.588	0.498
#    8	    linear	   0.01	    1.0 	0.260	0.577	0.501
#    8	    linear	    0.1	  0.001 	0.360	0.533	0.512
#    8	    linear	    0.1	    0.1 	0.334	0.529	0.523
#    8	    linear	    0.1	    0.2 	0.368	0.530	0.511
#    8	    linear	    0.1	    0.5 	0.369	0.515	0.523
#    8	    linear	    0.1	    0.7 	0.349	0.532	0.514
#    8	    linear	    0.1	    1.0 	0.352	0.513	0.529
#    8	    linear	    0.3	  0.001 	0.362	0.383	0.623
#    8	    linear	    0.3	    0.1 	0.346	0.379	0.630
#    8	    linear	    0.3	    0.2 	0.363	0.383	0.622
#    8	    linear	    0.3	    0.5 	0.384	0.420	0.589
#    8	    linear	    0.3	    0.7 	0.357	0.390	0.619
#    8	    linear	    0.3	    1.0 	0.376	0.374	0.625
#    8	    linear	    0.5	  0.001 	0.499	0.197	0.697
#    8	    linear	    0.5	    0.1 	0.499	0.209	0.690
#    8	    linear	    0.5	    0.2 	0.499	0.202	0.694
#    8	    linear	    0.5	    0.5 	0.500	0.203	0.694
#    8	    linear	    0.5	    0.7 	0.501	0.201	0.694
#    8	   sigmoid	    1.0	    0.7 	1.000	0.000	0.667
#    8	   sigmoid	    1.0	    1.0 	1.000	0.000	0.667
# done

# %%
plt.figure()

for n_components in performance_dbscan_tsne.keys():
    
    sorted_pairs = get_sorted_pairs_ocsvm(performance_ocsvm_tsne[n_components])
    curve_fpr, curve_fnr = get_curve(sorted_pairs)
    
    ax = plt.scatter([x for x, y in sorted_pairs if x not in curve_fpr and y not in curve_fnr], 
                [y for x, y in sorted_pairs if x not in curve_fpr and y not in curve_fnr], 
                marker='o', s=80, alpha=0.5, edgecolors='white', zorder=1)
    
    plt.plot(curve_fpr, curve_fnr, ls='--', marker='o', alpha=1., markeredgecolor='white', color=ax.get_facecolors()[0], zorder=10, label=str(n_components))
    
    best_f1 = get_best_ocsvm(performance_ocsvm_tsne[n_components])
    plt.annotate(f"{n_components} comp\nf1: {best_f1['f1_score']:.3f}", 
                 xy=(best_f1['false_positive_rate'], best_f1['false_negative_rate']), xycoords='data', 
                 xytext=(-0.05+n_components*.1, 1.-n_components*.12), textcoords='data',
                 color=ax.get_facecolors()[0],alpha=1.,
                 backgroundcolor="w",
                 arrowprops=dict(arrowstyle='->'),
                 zorder=20)
    
plt.xlabel('false positive')
plt.ylabel('false negative')
plt.legend(ncol=2)
plt.tight_layout()
plt.savefig('./figures/tsne_ocsvm.pdf')
plt.savefig('./figures/tsne_ocsvm.svg')
plt.show()

# %% [markdown]
# ### Comparing DBSCAN and OCSVM

# %%
with open('./models/tsne_results.h5', 'wb') as file:
    pickle.dump({
        'performance_ocsvm_tsne': performance_ocsvm_tsne,
        'performance_dbscan_tsne': performance_dbscan_tsne
    }, file)

# %%
plt.figure(figsize=(10, 8))# 

for n_components in performance_dbscan_tsne.keys():
    
    best_f1_dbscan = get_best_dbscan(performance_dbscan_tsne[n_components])
    ax = plt.scatter(best_f1_dbscan['false_positive_rate'], best_f1_dbscan['false_negative_rate'], marker='s', label=f'{n_components}')
    plt.annotate(f"{best_f1_dbscan['f1_score']:.3f}", xy=(best_f1_dbscan['false_positive_rate'], best_f1_dbscan['false_negative_rate']), color=ax.get_facecolors()[0])
    
    best_f1_ocsvm = get_best_ocsvm(performance_ocsvm_tsne[n_components])
    plt.scatter(best_f1_ocsvm['false_positive_rate'], best_f1_ocsvm['false_negative_rate'], marker='o', color=ax.get_facecolors()[0])
    plt.annotate(f"{best_f1_ocsvm['f1_score']:.3f}", xy=(best_f1_ocsvm['false_positive_rate'], best_f1_ocsvm['false_negative_rate']), color=ax.get_facecolors()[0])
    
plt.title('f1 score for TSNE w/ different # dimensions - DBSCAN (square) vs. OCSVM (circle)')
plt.xlabel('false positive')
plt.ylabel('false negative')
x_lim = plt.xlim()
y_lim = plt.ylim()
plt.xlim(x_lim[0], max(x_lim[1], y_lim[1]))
plt.ylim(y_lim[0], max(x_lim[1], y_lim[1]))
plt.legend(ncol=2)
plt.tight_layout()
plt.savefig('./figures/tsne_summary.pdf')
plt.savefig('./figures/tsne_summary.svg')
plt.show()
